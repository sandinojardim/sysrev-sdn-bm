# %%
import rispy

# %%
filepath = 'ieee_abs/IEEE Xplore Citation RIS Download 2023.10.30.14.59.40.ris'
with open(filepath, 'r') as bibliography_file:
    entries = rispy.load(bibliography_file)
    for entry in entries:
        print(entry['title'])
        print('-----')
        print(entry['abstract'])
        print('-----\n-----')
# Out:
# Performance Analysis of Between Software Defined Wireless Network and Mobile Ad Hoc Network Under DoS Attack
# -----
# ...
